# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("Z:\Internship\Tasks\Edge Detection\pic5.jpeg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (3, 3), 0).astype(np.float32)

shifted = np.roll(blurred, shift=1, axis=0)
shifted = np.roll(shifted, shift=1, axis=1).astype(np.float32)

subtract = np.abs(blurred - shifted)

edges = cv2.normalize(subtract, 0, 255, cv2.NORM_MINMAX)

plt.imshow(img, cmap='gray')
plt.show()

plt.imshow( edges,cmap='gray')
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\HP\AppData\Local\Temp\ipykernel_3980\1343987949.py:5: SyntaxWarning: invalid escape sequence '\I'
#   img = cv2.imread("Z:\Internship\Tasks\Edge Detection\pic5.jpeg")

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread("Z:\Internship\Tasks\Edge Detection\pic5.jpeg")
gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blurred=cv2.GaussianBlur(gray,(5,5),0).astype(np.float32)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\HP\AppData\Local\Temp\ipykernel_3980\2750772206.py:1: SyntaxWarning: invalid escape sequence '\I'
#   img=cv2.imread("Z:\Internship\Tasks\Edge Detection\pic5.jpeg")

# %%
shift=np.roll(blurred,shift=1,axis=1)
shift=np.roll(shift,shift=1,axis=0)

# %%
subtract=np.abs(shift-blurred)

# %%
edges=cv2.normalize(subtract,cv2.NORM_MINMAX)

# %%
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 plt.imshow(img,cv2.COLOR_BGR2GRAY)
#       2 plt.show()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:3592, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.imshow)
#    3571 def imshow(
#    3572     X: ArrayLike | PIL.Image.Image,
#    (...)   3590     **kwargs,
#    3591 ) -> AxesImage:
# -> 3592     __ret = gca().imshow(
#    3593         X,
#    3594         cmap=cmap,
#    3595         norm=norm,
#    3596         aspect=aspect,
#    3597         interpolation=interpolation,
#    3598         alpha=alpha,
#    3599         vmin=vmin,
#    3600         vmax=vmax,
# ...

# %%
plt.imshow(edges, cmap='grey')
plt.show()
