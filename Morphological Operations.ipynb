# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("Z:\Internship\Tasks\Edge Detection\pic6.jpeg",0)

kernel = np.ones((2,2))

erosion = cv2.erode(image, kernel, iterations=1)

dilation = cv2.dilate(image, kernel, iterations=1)
 
opening = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
 
closing = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)

titles = ['Original Image', 'Erosion', 'Dilation', 'Opening', 'Closing']
images = [image, erosion, dilation, opening, closing]

for i in range(5):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\HP\AppData\Local\Temp\ipykernel_13220\4021474322.py:5: SyntaxWarning: invalid escape sequence '\I'
#   image = cv2.imread("Z:\Internship\Tasks\Edge Detection\pic6.jpeg",0)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("Z:\Internship\Tasks\Edge Detection\pic6.jpeg",0)

blurred=cv2.GaussianBlur(image,(3,3),0)

kernel = np.ones((1,1))

a,binary=cv2.threshold(blurred,130,255,cv2.THRESH_BINARY)

opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)

closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel)

plt.imshow(closing,cmap='gray')
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# <>:5: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\HP\AppData\Local\Temp\ipykernel_13220\974839277.py:5: SyntaxWarning: invalid escape sequence '\I'
#   image = cv2.imread("Z:\Internship\Tasks\Edge Detection\pic6.jpeg",0)
